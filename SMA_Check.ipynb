# %%
from SMABacktester import SMABacktester

# %%
tester_spy = SMABacktester("SPY", 50, 100, "2000-01-01", "2020-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tester_spy.test_results()
# Out:
# (2.592726, 0.297824)

# %%
tester_spy.plot_results()

# %%
tester_aapl = SMABacktester("AAPL", 1, 200, "2000-01-01", "2020-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tester_aapl.test_results()
# Out:
# (239.027886, 47.814157)

# %%
tester_aapl.plot_results()

# %%
from WeinsteinBacktester import WeinsteinBacktester

# %%
Wtester_spy = WeinsteinBacktester("SPY", "2000-01-01", "2020-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Wtester_spy.test_results()
# Out:
# (2.433645, 0.143336)

# %%
Wtester_spy.plot_results()

# %%
Wtester_aapl = WeinsteinBacktester("AAPL", "2000-01-01", "2020-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Wtester_aapl.test_results()
# Out:
# (190.067114, -22.805413)

# %%
Wtester_aapl.plot_results()
